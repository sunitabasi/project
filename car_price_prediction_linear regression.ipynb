# %%
# !pip install seaborn

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib.pyplot import yticks

# %%
df = pd.DataFrame(pd.read_csv("updated_cardata.csv", index_col=0))
df
# Out:
#      car_brand  carprice['000']  kms_driven fuel_type       city  \
# 0      Hyundai            445.0     22402.0    Petrol     Mumbai
# 1       Maruti            293.0     10344.0    Petrol    Kolkata
# 2         Tata           2249.0     12999.0    Diesel  Bangalore
# 3       Maruti            695.0     45000.0    Petrol      Thane
# 4         Jeep           1200.0     11193.0    Petrol    Kolkata
# ...        ...              ...         ...       ...        ...
# 2100      Ford            360.0     42158.0    Diesel    Kolkata
# 2101      MINI           2200.0     68862.0    Diesel  Hyderabad
# 2102   Hyundai            838.0     37622.0    Petrol    Chennai
# 2103    Maruti            675.0     64726.0    Petrol     Mumbai
# 2104   Hyundai            876.0     29150.0    Petrol       Pune
#
#       year_of_manufacture
# 0                    2016
# 1                    2019
# 2                    2021
# 3                    2016
# 4                    2019
# ...

# %%
row,col = df.shape
print("No of rows = ",row)
print("No of cols = ",col)
# Out:
# No of rows =  2009
# No of cols =  6

# %%
df.describe()
# Out:
#        carprice['000']    kms_driven  year_of_manufacture
# count      2009.000000  2.009000e+03          2009.000000
# mean       1217.510204  4.843985e+04          2017.022897
# std        2901.518120  8.550894e+04             2.821459
# min         110.000000  6.400000e+01          2004.000000
# 25%         475.000000  2.500000e+04          2015.000000
# 50%         699.000000  4.290600e+04          2017.000000
# 75%        1150.000000  6.300000e+04          2019.000000
# max       99991.000000  3.600000e+06          2022.000000

# %%
df.isna().sum()
# Out:
# car_brand              0
# carprice['000']        0
# kms_driven             0
# fuel_type              0
# city                   0
# year_of_manufacture    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# car_brand              0
# carprice['000']        0
# kms_driven             0
# fuel_type              0
# city                   0
# year_of_manufacture    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['car_brand', 'carprice['000']', 'kms_driven', 'fuel_type', 'city',
#        'year_of_manufacture'],
#       dtype='object')

# %%
df.shape
# Out:
# (2009, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2009 entries, 0 to 2104
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_brand            2009 non-null   object
#  1   carprice['000']      2009 non-null   float64
#  2   kms_driven           2009 non-null   float64
#  3   fuel_type            2009 non-null   object
#  4   city                 2009 non-null   object
#  5   year_of_manufacture  2009 non-null   int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 109.9+ KB

# %%
# # Checking Null values
# df.isnull().sum()
# # There are no NULL values in the dataset, hence it is clean.

# %%
print(len(set(df['car_brand'])))   #categorical variabel mustnot be large number which may not be useful
print(len(set(df['fuel_type'])))
print(len(set(df['city'])))
# Out:
# 28
# 3
# 16

# %%
# cleaning year of manufacture variable
df['age'] = df.apply(lambda row: 2024 - row["year_of_manufacture"], axis=1)
df
# Out:
#      car_brand  carprice['000']  kms_driven fuel_type       city  \
# 0      Hyundai            445.0     22402.0    Petrol     Mumbai
# 1       Maruti            293.0     10344.0    Petrol    Kolkata
# 2         Tata           2249.0     12999.0    Diesel  Bangalore
# 3       Maruti            695.0     45000.0    Petrol      Thane
# 4         Jeep           1200.0     11193.0    Petrol    Kolkata
# ...        ...              ...         ...       ...        ...
# 2100      Ford            360.0     42158.0    Diesel    Kolkata
# 2101      MINI           2200.0     68862.0    Diesel  Hyderabad
# 2102   Hyundai            838.0     37622.0    Petrol    Chennai
# 2103    Maruti            675.0     64726.0    Petrol     Mumbai
# 2104   Hyundai            876.0     29150.0    Petrol       Pune
#
#       year_of_manufacture  age
# 0                    2016    8
# 1                    2019    5
# 2                    2021    3
# 3                    2016    8
# ...

# %%
df.drop(columns=['year_of_manufacture'], inplace=True)

# %%
car_dataset=df[['car_brand', "carprice['000']", 'kms_driven', 'fuel_type','city','age']]

# %%
sns.pairplot(car_dataset) #compare two dependent variable

# %%
car_dataset1=df[['age', "carprice['000']",'kms_driven']]
car_dataset1.corr()
# Out:
#                       age  carprice['000']  kms_driven
# age              1.000000        -0.029250    0.164576
# carprice['000'] -0.029250         1.000000   -0.004238
# kms_driven       0.164576        -0.004238    1.000000

# %%
# Starting machine learning
import seaborn as sns
plt.figure(figsize=(15,5))
sns.heatmap(auto1.corr(),annot=True)
plt.show()

# %%
car_dataset
# Out:
#      car_brand  carprice['000']  kms_driven fuel_type       city  age
# 0      Hyundai            445.0     22402.0    Petrol     Mumbai    8
# 1       Maruti            293.0     10344.0    Petrol    Kolkata    5
# 2         Tata           2249.0     12999.0    Diesel  Bangalore    3
# 3       Maruti            695.0     45000.0    Petrol      Thane    8
# 4         Jeep           1200.0     11193.0    Petrol    Kolkata    5
# ...        ...              ...         ...       ...        ...  ...
# 2100      Ford            360.0     42158.0    Diesel    Kolkata    9
# 2101      MINI           2200.0     68862.0    Diesel  Hyderabad   11
# 2102   Hyundai            838.0     37622.0    Petrol    Chennai    6
# 2103    Maruti            675.0     64726.0    Petrol     Mumbai    7
# 2104   Hyundai            876.0     29150.0    Petrol       Pune    7
#
# [2009 rows x 6 columns]

# %%
# Dimension reduction- it is the process of converting categorical value to number i.e gender and education level

# %%
#drop_first = True - this function assign true value to male in gender column

fuel = pd.get_dummies(car_dataset['fuel_type'], drop_first = False)  # it converts the numerical value to boolean value
fuel
# Out:
#       Diesel  Petrol  eco_fuel
# 0      False    True     False
# 1      False    True     False
# 2       True   False     False
# 3      False    True     False
# 4      False    True     False
# ...      ...     ...       ...
# 2100    True   False     False
# 2101    True   False     False
# 2102   False    True     False
# 2103   False    True     False
# 2104   False    True     False
#
# [2009 rows x 3 columns]

# %%
# encoding "Fuel_Type" Column in alternate ways
car_dataset.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)

# %%
car_dataset = pd.concat([car_dataset, fuel], axis = 1)   # auto- original data frame and gender is boolean value
car_dataset
# Out:
#      car_brand  carprice['000']  kms_driven fuel_type       city  age  Diesel  \
# 0      Hyundai            445.0     22402.0    Petrol     Mumbai    8   False
# 1       Maruti            293.0     10344.0    Petrol    Kolkata    5   False
# 2         Tata           2249.0     12999.0    Diesel  Bangalore    3    True
# 3       Maruti            695.0     45000.0    Petrol      Thane    8   False
# 4         Jeep           1200.0     11193.0    Petrol    Kolkata    5   False
# ...        ...              ...         ...       ...        ...  ...     ...
# 2100      Ford            360.0     42158.0    Diesel    Kolkata    9    True
# 2101      MINI           2200.0     68862.0    Diesel  Hyderabad   11    True
# 2102   Hyundai            838.0     37622.0    Petrol    Chennai    6   False
# 2103    Maruti            675.0     64726.0    Petrol     Mumbai    7   False
# 2104   Hyundai            876.0     29150.0    Petrol       Pune    7   False
#
#       Petrol  eco_fuel
# ...

# %%
car_dataset['car_brand'].value_counts()
# Out:
# car_brand
# Maruti           539
# Hyundai          415
# Honda            220
# Toyota            86
# Tata              81
# Ford              69
# Mercedes-Benz     68
# Renault           65
# Mahindra          64
# Audi              62
# Volkswagen        59
# BMW               55
# Skoda             45
# Kia               39
# Jeep              26
# MG                24
# Nissan            18
# Land              18
# Volvo             13
# Datsun            13
# Jaguar             9
# Chevrolet          6
# Isuzu              4
# MINI               4
# Fiat               3
# Porsche            2
# Citroen            1
# Bentley            1
# Name: count, dtype: int64

# %%
car_dataset = car_dataset.drop(['fuel_type'],axis = 1) #dropping original columns, axis =1 will add new column
car_dataset                                                                                # axis=0 will add new row
# Out:
#      car_brand  carprice['000']  kms_driven       city  age  Diesel  Petrol  \
# 0      Hyundai            445.0     22402.0     Mumbai    8   False    True
# 1       Maruti            293.0     10344.0    Kolkata    5   False    True
# 2         Tata           2249.0     12999.0  Bangalore    3    True   False
# 3       Maruti            695.0     45000.0      Thane    8   False    True
# 4         Jeep           1200.0     11193.0    Kolkata    5   False    True
# ...        ...              ...         ...        ...  ...     ...     ...
# 2100      Ford            360.0     42158.0    Kolkata    9    True   False
# 2101      MINI           2200.0     68862.0  Hyderabad   11    True   False
# 2102   Hyundai            838.0     37622.0    Chennai    6   False    True
# 2103    Maruti            675.0     64726.0     Mumbai    7   False    True
# 2104   Hyundai            876.0     29150.0       Pune    7   False    True
#
#       eco_fuel
# 0        False
# 1        False
# ...

# %%
#splliting the data and target
X = car_dataset.drop(['car_brand','city',"carprice['000']"],axis=1)
Y = car_dataset["carprice['000']"]

# %%
print(X)
# Out:
#       kms_driven  age  Diesel  Petrol  eco_fuel
# 0        22402.0    8   False    True     False
# 1        10344.0    5   False    True     False
# 2        12999.0    3    True   False     False
# 3        45000.0    8   False    True     False
# 4        11193.0    5   False    True     False
# ...          ...  ...     ...     ...       ...
# 2100     42158.0    9    True   False     False
# 2101     68862.0   11    True   False     False
# 2102     37622.0    6   False    True     False
# 2103     64726.0    7   False    True     False
# 2104     29150.0    7   False    True     False
#
# [2009 rows x 5 columns]

# %%
print(Y)
# Out:
# 0        445.0
# 1        293.0
# 2       2249.0
# 3        695.0
# 4       1200.0
#          ...
# 2100     360.0
# 2101    2200.0
# 2102     838.0
# 2103     675.0
# 2104     876.0
# Name: carprice['000'], Length: 2009, dtype: float64

# %%
#Splitting Training and Test data

# %%
 from sklearn.model_selection import train_test_split
# # We specify this so that the train and test data set always have the same rows, respectively
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, random_state=2)

# %%
X_train.shape
# Out:
# (1808, 5)

# %%
X_test.shape
# Out:
# (201, 5)

# %%
#Model tranining- linear regression
# loading the linear regression model
from sklearn.linear_model import LinearRegression
lin_reg_model = LinearRegression()
lin_reg_model.fit(X_train,Y_train)

from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, Y_train)
# Out:
# LinearRegression()

# %%
# prediction on Training data
from sklearn import metrics
training_data_prediction = lin_reg_model.predict(X_train)
# R squared Error-how well the model's predictions fit the actual data, with values closer to 1 indicating a better fit and values closer to 0 indicating a poorer fit.
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared Error : ", error_score)
#r square error indicates the goodness of fit of your regression model.
# Out:
# R squared Error :  0.026760457284033312

# %%
training_data_prediction = pol_reg.predict(poly_reg.fit_transform(X_train))

error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.021616094684993814

# %%
# it seems that there is high accuracy with linear model

# %%
#Visualize the actual prices and Predicted prices
plt.scatter(Y_train, training_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
# prediction on Training data
test_data_prediction = lin_reg_model.predict(X_test)

# %%
# R squared Error
error_score = metrics.r2_score(Y_test, test_data_prediction)
print("R squared Error : ", error_score)
# Out:
# R squared Error :  0.1921429239678466

# %%
plt.scatter(Y_test, test_data_prediction)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
# it seems that there is no proper corelation between these variables as there is no any diagonal linear line.
